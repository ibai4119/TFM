# %%
from flow import retrieve_flows_and_save_csv
for i in range(4,5):
    retrieve_flows_and_save_csv(5 ,year=2023,month=i)
# Out:
# {'totalItems': 280954, 'totalPages': 14048, 'currentPage': 1, 'flows': [{'meterId': '489', 'sourceId': '5', 'meterDate': '2023-04-04', 'timeRank': '16:15', 'speedAvg': '16', 'totalVehicles': '76', 'speedIntervals': [], 'lengthIntervals': []}, {'meterId': '490', 'sourceId': '5', 'meterDate': '2023-04-04', 'timeRank': '16:15', 'speedAvg': '8', 'totalVehicles': '781', 'speedIntervals': [], 'lengthIntervals': []}, {'meterId': '491', 'sourceId': '5', 'meterDate': '2023-04-04', 'timeRank': '16:15', 'speedAvg': '11', 'totalVehicles': '514', 'speedIntervals': [], 'lengthIntervals': []}, {'meterId': '492', 'sourceId': '5', 'meterDate': '2023-04-04', 'timeRank': '16:15', 'speedAvg': '35', 'totalVehicles': '929', 'speedIntervals': [], 'lengthIntervals': []}, {'meterId': '493', 'sourceId': '5', 'meterDate': '2023-04-04', 'timeRank': '16:15', 'speedAvg': '9', 'totalVehicles': '558', 'speedIntervals': [], 'lengthIntervals': []}, {'meterId': '495', 'sourceId': '5', 'meterDate': '2023-04-04', 'timeR
# ...
