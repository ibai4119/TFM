# %%
from meters import retrieve_meters_and_save_csv

# %%
for id in range(1,8):
    retrieve_meters_and_save_csv(id=id)
# Out:
# {'totalItems': 386, 'totalPages': 4, 'currentPage': 1, 'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'meterId': '383', 'sourceId': '1', 'meterCode': '309', 'system': 'GI-20', 'etd': '[ GI-20 ] 06-ETD-01 Ondarreta, GI-20 pk 13, GI-20 pk 13', 'detector': 'Lento Bilbao', 'description': 'GI-20 - [ GI-20 ] 06-ETD-01 Ondarreta, GI-20 pk 13, GI-20 pk 13 - Lento Bilbao', 'provinceId': '20', 'province': 'Gipuzkoa', 'municipalityId': '69', 'municipality': 'Donostia / San Sebastián', 'latitude': '43.288', 'longitude': '-2.0063'}, 'geometry': {'type': 'Point', 'coordinates': [-2.0063, 43.288]}}, {'type': 'Feature', 'properties': {'meterId': '384', 'sourceId': '1', 'meterCode': '312', 'system': 'GI-20', 'etd': '[ GI-20 ] 06-ETD-01 Ondarreta, GI-20 pk 13, GI-20 pk 13', 'detector': 'Rapido Donosti', 'description': 'GI-20 - [ GI-20 ] 06-ETD-01 Ondarreta, GI-20 pk 13, GI-20 pk 13 - Rapido Donosti', 'provinceId': '20', 'province': 'Gipuzkoa', 'municipalityId': '69', 'mun
# ...
