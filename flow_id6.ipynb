# %%
from flow import retrieve_flows_and_save_csv
for month in range(6,13):
    retrieve_flows_and_save_csv(6 ,year=2022,month=month)
# Out:
# {'totalItems': 868224, 'totalPages': 43412, 'currentPage': 1, 'flows': [{'meterId': '7235', 'sourceId': '6', 'meterDate': '2022-06-08', 'timeRank': '01:30 - 01:45', 'totalVehicles': '3', 'speedIntervals': [], 'lengthIntervals': []}, {'meterId': '4995', 'sourceId': '6', 'meterDate': '2022-06-08', 'timeRank': '01:30 - 01:45', 'totalVehicles': '4', 'speedIntervals': [], 'lengthIntervals': []}, {'meterId': '4998', 'sourceId': '6', 'meterDate': '2022-06-08', 'timeRank': '01:30 - 01:45', 'totalVehicles': '12', 'speedIntervals': [], 'lengthIntervals': []}, {'meterId': '4999', 'sourceId': '6', 'meterDate': '2022-06-08', 'timeRank': '01:30 - 01:45', 'totalVehicles': '1', 'speedIntervals': [], 'lengthIntervals': []}, {'meterId': '5000', 'sourceId': '6', 'meterDate': '2022-06-08', 'timeRank': '01:30 - 01:45', 'totalVehicles': '0', 'speedIntervals': [], 'lengthIntervals': []}, {'meterId': '3321', 'sourceId': '6', 'meterDate': '2022-06-08', 'timeRank': '01:30 - 01:45', 'totalVehicles': '5', 'spee
# ...
